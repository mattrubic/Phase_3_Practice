# %%
import pandas as pd
import sqlite3

# %%
players_batting = pd.read_csv('./Data/players_batting.csv')

# %%
players_batting.head()
# Out:
#    player_id  team_id  league_id  position  role  \
# 0          1        0          0         3     0
# 1          2       42        203         3     0
# 2          3        0          0         6     0
# 3          4      470        209         3     0
# 4          5        0          0         1    11
#
#    batting_ratings_overall_contact  batting_ratings_overall_gap  \
# 0                               22                           22
# 1                               89                           73
# 2                               18                           11
# 3                               56                           74
# 4                               13                           52
#
#    batting_ratings_overall_eye  batting_ratings_overall_strikeouts  \
# 0                           35                                  33
# 1                          130                                 142
# 2                           16                                  49
# ...
